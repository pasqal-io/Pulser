# %% [markdown]
# # Pulser: Quick Run Guide
#
# Design and simulate pulse sequences for quantum hardware and simulations.

# %% [markdown]
# Designed to get you up and running as quickly as possible, covering installation, running a job locally, and submitting to remote backends. It is intentionally focused and does not replace the full Pulser documentation. For an in-depth understanding of the library, we recommend following the complete documentation in order.

# %% [markdown]
# ## Installation
